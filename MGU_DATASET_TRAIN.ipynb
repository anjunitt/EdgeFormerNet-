# %%
# === Optimized EdgeFormerNet++ Training Code for Dice > 0.85 ===  - TRAINING THE MODEL

import os
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.layers import (
    LayerNormalization, MultiHeadAttention, Dense, Dropout, Add,
    GlobalAveragePooling2D, Multiply, Conv2D, Reshape, Concatenate,
    BatchNormalization, Conv2DTranspose, Activation, ReLU, MaxPooling2D
)
from tensorflow.keras.utils import Sequence
import albumentations as A
from albumentations.core.composition import OneOf
# EdgeFormerNet++: OCT Layer Segmentation with Res2Net - FINAL MODEL
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.layers import *
from tensorflow.keras.initializers import GlorotUniform

initializer = GlorotUniform(seed=42)

# === Edge Attention Block ===
def edge_attention_block(input_tensor):
    edge = tf.image.sobel_edges(input_tensor)
    edge = tf.reduce_sum(edge, axis=-1)
    edge = tf.reduce_mean(edge, axis=-1, keepdims=True)
    edge = Conv2D(16, (3, 3), padding='same', activation='relu')(edge)
    edge = Conv2D(1, (1, 1), activation='sigmoid')(edge)
    return Multiply()([input_tensor, edge])

# === CBAM Module ===
def cbam_block(x, ratio=8):
    channel = x.shape[-1]
    shared_dense = [
        Dense(channel // ratio, activation='relu'),
        Dense(channel)
    ]
    avg_pool = GlobalAveragePooling2D()(x)
    avg_pool = shared_dense[0](avg_pool)
    avg_pool = shared_dense[1](avg_pool)
    max_pool = GlobalMaxPooling2D()(x)
    max_pool = shared_dense[0](max_pool)
    max_pool = shared_dense[1](max_pool)
    cbam_feature = Add()([avg_pool, max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)
    cbam_feature = Multiply()([x, cbam_feature])
    return cbam_feature

# === SCSE Module ===
def scse_block(x):
    channel = x.shape[-1]
    se = GlobalAveragePooling2D()(x)
    se = Dense(channel // 2, activation='relu')(se)
    se = Dense(channel, activation='sigmoid')(se)
    se = Multiply()([x, se])
    spatial = Conv2D(1, (1, 1), activation='sigmoid')(x)
    spatial = Multiply()([x, spatial])
    return Add()([se, spatial])

# === Transformer Block ===
def transformer_block(x, num_heads=4, ff_dim=128):
    x_norm = LayerNormalization()(x)
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim)(x_norm, x_norm)
    x = Add()([x, attn_output])
    ffn_output = Dense(ff_dim, activation='relu')(x)
    ffn_output = Dense(x.shape[-1])(ffn_output)
    return Add()([x, ffn_output])

# === Res2Net Block ===
def res2net_block(x, filters, scale=4):
    input_channels = x.shape[-1]
    split_channels = filters // scale
    convs = []
    for s in range(scale):
        if s == 0:
            conv = Conv2D(split_channels, (3, 3), padding='same', activation='relu')(x)
        else:
            prev = convs[-1]
            shortcut = Lambda(lambda z: z[:, :, :, :split_channels])(x) if input_channels >= split_channels else x
            added = Add()([prev, shortcut])
            conv = Conv2D(split_channels, (3, 3), padding='same', activation='relu')(added)
        convs.append(conv)
    out = Concatenate()(convs)
    out = Conv2D(filters, (1, 1), padding='same')(out)
    return out

# === Encoder using Res2Net ===
def encoder_res2net(input_tensor):
    skips = []
    x = Conv2D(32, (3, 3), strides=(1, 1), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    for filters in [64, 128, 256, 512]:
        x = res2net_block(x, filters)
        skips.append(x)
        x = MaxPooling2D((2, 2))(x)
    return x, skips[::-1]  # reverse for decoder

# === Decoder Block ===
def decoder_block(x, skip, filters):
    x = Conv2DTranspose(filters, (3, 3), strides=(2, 2), padding='same')(x)
    x = Concatenate()([x, skip])
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

# === Full Model ===
def build_edgeformernet(input_shape=(384, 256, 1), num_classes=9):
    inputs = Input(shape=input_shape)
    edge_feat = edge_attention_block(inputs)
    x = Concatenate()([inputs, edge_feat])

    x, skips = encoder_res2net(x)

    x = transformer_block(x)
    x = cbam_block(x)

    d4 = decoder_block(x, skips[0], 256)
    d4 = cbam_block(d4)
    d4 = scse_block(d4)

    d3 = decoder_block(d4, skips[1], 128)
    d2 = decoder_block(d3, skips[2], 64)
    d1 = decoder_block(d2, skips[3], 32)

    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(d1)

    return models.Model(inputs, outputs, name='EdgeFormerNetPlus')

# === Example ===
model = build_edgeformernet()
model.summary()
# === CONFIG ===
img_height, img_width = 384, 256
batch_size = 4
epochs = 400
initializer = tf.keras.initializers.GlorotUniform(seed=42)

# === Mask Color Mapping ===
def extract_unique_colors(mask_dir):
    unique_colors = set()
    for fname in os.listdir(mask_dir):
        if fname.endswith(('.png', '.bmp')):
            mask = np.array(Image.open(os.path.join(mask_dir, fname)).convert('RGB'))
            colors = np.unique(mask.reshape(-1, 3), axis=0)
            for c in map(tuple, colors):
                unique_colors.add(c)
    return sorted(list(unique_colors))

train_lbl_dir = r"D:\layer\oct_dataset\oct_dataset\train\mask"
UNIQUE_COLORS = extract_unique_colors(train_lbl_dir)
COLOR_TO_INDEX = {color: idx for idx, color in enumerate(UNIQUE_COLORS)}
INDEX_TO_COLOR = {idx: color for color, idx in COLOR_TO_INDEX.items()}
num_classes = len(COLOR_TO_INDEX)

# === Load Image/Mask Pair ===
def load_image_mask_pair(image_path, mask_path):
    image = Image.open(image_path).resize((img_width, img_height))
    image = np.array(image, dtype=np.float32) / 255.0
    if image.ndim == 2:
        image = np.stack([image] * 3, axis=-1)

    mask = Image.open(mask_path).convert('RGB').resize((img_width, img_height), resample=Image.NEAREST)
    mask = np.array(mask)
    mask_indexed = np.zeros((img_height, img_width), dtype=np.uint8)
    for color, idx in COLOR_TO_INDEX.items():
        mask_indexed[np.all(mask == color, axis=-1)] = idx
    return image, mask_indexed

# === Dataset Loader ===
def load_dataset(image_dir, mask_dir):
    image_files = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(('.png', '.bmp'))])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith(('.png', '.bmp'))])
    images, masks = [], []
    for img_path, msk_path in zip(image_files, mask_files):
        img, msk = load_image_mask_pair(img_path, msk_path)
        images.append(img)
        masks.append(msk)
    return np.array(images), np.array(masks)

# === Augmentation ===
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomRotate90(p=0.3),
    A.ElasticTransform(p=0.4),
    A.GridDistortion(p=0.2),
    A.RandomBrightnessContrast(p=0.4),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=15, p=0.4),
    A.CLAHE(p=0.2),
    OneOf([
        A.GaussianBlur(blur_limit=(3, 5)),
        A.MedianBlur(blur_limit=5),
        A.GaussNoise(var_limit=(10.0, 50.0))
    ], p=0.3)
])

# === Custom Data Generator ===
class CustomDataGenerator(Sequence):
    def __init__(self, images, masks, batch_size, transform=None):
        self.images = images
        self.masks = masks
        self.batch_size = batch_size
        self.transform = transform

    def __len__(self):
        return len(self.images) // self.batch_size

    def __getitem__(self, idx):
        batch_images = self.images[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_masks = self.masks[idx * self.batch_size:(idx + 1) * self.batch_size]
        aug_imgs, aug_masks = [], []
        for img, mask in zip(batch_images, batch_masks):
            augmented = self.transform(image=img, mask=mask) if self.transform else {'image': img, 'mask': mask}
            aug_imgs.append(np.resize(augmented['image'], (img_height, img_width, 3)).astype(np.float32))
            aug_masks.append(np.resize(augmented['mask'], (img_height, img_width)).astype(np.uint8))
        return np.stack(aug_imgs), np.stack(aug_masks)

# === Loss Functions ===
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2])
    return 1.0 - tf.reduce_mean((2. * intersection + smooth) / (union + smooth))

def tversky_loss(y_true, y_pred, alpha=0.6, beta=0.4, smooth=1e-6):
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)
    TP = tf.reduce_sum(y_true * y_pred, axis=[1,2])
    FP = tf.reduce_sum((1 - y_true) * y_pred, axis=[1,2])
    FN = tf.reduce_sum(y_true * (1 - y_pred), axis=[1,2])
    return tf.reduce_mean(1 - (TP + smooth) / (TP + alpha * FP + beta * FN + smooth))

def hybrid_loss(y_true, y_pred):
    return 0.5 * dice_loss(y_true, y_pred) + 0.5 * tversky_loss(y_true, y_pred)

def dice_metric(y_true, y_pred, smooth=1e-6):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_pred = tf.one_hot(y_pred, depth=num_classes)
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2])
    return tf.reduce_mean((2. * intersection + smooth) / (union + smooth))

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_pred = tf.argmax(y_pred, axis=-1)
    y_pred = tf.one_hot(y_pred, depth=num_classes)
    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2]) - intersection
    return tf.reduce_mean((intersection + smooth) / (union + smooth))

# === Load Data ===
train_img_dir = r"D:\layer\oct_dataset\oct_dataset\train\img"
val_img_dir = r"D:\layer\oct_dataset\oct_dataset\eval\img"
val_lbl_dir = r"D:\layer\oct_dataset\oct_dataset\eval\mask"
X_train, y_train = load_dataset(train_img_dir, train_lbl_dir)
X_val, y_val = load_dataset(val_img_dir, val_lbl_dir)
train_gen = CustomDataGenerator(X_train, y_train, batch_size=batch_size, transform=train_transform)
val_gen = CustomDataGenerator(X_val, y_val, batch_size=batch_size)

# === Build Model ===
model = build_edgeformernet(input_shape=(img_height, img_width, 3), num_classes=num_classes)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=hybrid_loss,
              metrics=[dice_metric, iou_metric])

# === Training Callbacks ===
callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint("EdgeFormer_Dice85_best_val_loss_{val_loss:.6f}.h5", save_best_only=True, monitor='val_loss'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=30, min_lr=1e-6)
]

# === Train ===
history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, callbacks=callbacks)
# Out:
# C:\Users\VPG\.conda\envs\micaih_clean\lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Model: "EdgeFormerNetPlus"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 384, 256, 1  0           []
#                                 )]
#
#  tf.compat.v1.shape (TFOpLambda  (4,)                0           ['input_1[0][0]']
#  )
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.compat.v1.pad (TFOpLambda)  (None, 386, 258, 1)  0           ['input_1[0][0]']
#
#  tf.tile (TFOpLambda)           (3, 3, 1, 2)         0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.compat.v1.nn.depthwise_conv  (None, 384, 256, 2)  0          ['tf.compat.v1.pad[0][0]',
#  2d (TFOpLambda)                                                  'tf.tile[0][0]']
#
#  tf.concat (TFOpLambda)         (5,)                 0           ['tf.compat.v1.shape[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 384, 256, 1,  0           ['tf.compat.v1.nn.depthwise_conv2
#                                  2)                              d[0][0]',
#                                                                   'tf.concat[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 384, 256, 1)  0          ['tf.reshape[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (None, 384, 256, 1)  0          ['tf.math.reduce_sum[0][0]']
#  a)
#
#  conv2d (Conv2D)                (None, 384, 256, 16  160         ['tf.math.reduce_mean[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 384, 256, 1)  17          ['conv2d[0][0]']
#
#  multiply (Multiply)            (None, 384, 256, 1)  0           ['input_1[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 384, 256, 2)  0           ['input_1[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 384, 256, 32  608         ['concatenate[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 384, 256, 32  128        ['conv2d_2[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 384, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 384, 256, 16  4624        ['re_lu[0][0]']
#                                 )
#
#  lambda (Lambda)                (None, 384, 256, 16  0           ['re_lu[0][0]']
#                                 )
#
#  add (Add)                      (None, 384, 256, 16  0           ['conv2d_3[0][0]',
#                                 )                                 'lambda[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 384, 256, 16  2320        ['add[0][0]']
#                                 )
#
#  lambda_1 (Lambda)              (None, 384, 256, 16  0           ['re_lu[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 384, 256, 16  0           ['conv2d_4[0][0]',
#                                 )                                 'lambda_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 384, 256, 16  2320        ['add_1[0][0]']
#                                 )
#
#  lambda_2 (Lambda)              (None, 384, 256, 16  0           ['re_lu[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 384, 256, 16  0           ['conv2d_5[0][0]',
#                                 )                                 'lambda_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 384, 256, 16  2320        ['add_2[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 384, 256, 64  0           ['conv2d_3[0][0]',
#                                 )                                 'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 384, 256, 64  4160        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 192, 128, 64  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 192, 128, 32  18464       ['max_pooling2d[0][0]']
#                                 )
#
#  lambda_3 (Lambda)              (None, 192, 128, 32  0           ['max_pooling2d[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 192, 128, 32  0           ['conv2d_8[0][0]',
#                                 )                                 'lambda_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 192, 128, 32  9248        ['add_3[0][0]']
#                                 )
#
#  lambda_4 (Lambda)              (None, 192, 128, 32  0           ['max_pooling2d[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 192, 128, 32  0           ['conv2d_9[0][0]',
#                                 )                                 'lambda_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 192, 128, 32  9248        ['add_4[0][0]']
#                                 )
#
#  lambda_5 (Lambda)              (None, 192, 128, 32  0           ['max_pooling2d[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 192, 128, 32  0           ['conv2d_10[0][0]',
#                                 )                                 'lambda_5[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 192, 128, 32  9248        ['add_5[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 192, 128, 12  0           ['conv2d_8[0][0]',
#                                 8)                                'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 192, 128, 12  16512       ['concatenate_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 96, 64, 128)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 96, 64, 64)   73792       ['max_pooling2d_1[0][0]']
#
#  lambda_6 (Lambda)              (None, 96, 64, 64)   0           ['max_pooling2d_1[0][0]']
#
#  add_6 (Add)                    (None, 96, 64, 64)   0           ['conv2d_13[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 96, 64, 64)   36928       ['add_6[0][0]']
#
#  lambda_7 (Lambda)              (None, 96, 64, 64)   0           ['max_pooling2d_1[0][0]']
#
#  add_7 (Add)                    (None, 96, 64, 64)   0           ['conv2d_14[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 96, 64, 64)   36928       ['add_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 96, 64, 64)   0           ['max_pooling2d_1[0][0]']
#
#  add_8 (Add)                    (None, 96, 64, 64)   0           ['conv2d_15[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 64, 64)   36928       ['add_8[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 96, 64, 256)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 96, 64, 256)  65792       ['concatenate_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 48, 32, 256)  0          ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 48, 32, 128)  295040      ['max_pooling2d_2[0][0]']
#
#  lambda_9 (Lambda)              (None, 48, 32, 128)  0           ['max_pooling2d_2[0][0]']
#
#  add_9 (Add)                    (None, 48, 32, 128)  0           ['conv2d_18[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 48, 32, 128)  147584      ['add_9[0][0]']
#
#  lambda_10 (Lambda)             (None, 48, 32, 128)  0           ['max_pooling2d_2[0][0]']
#
#  add_10 (Add)                   (None, 48, 32, 128)  0           ['conv2d_19[0][0]',
#                                                                   'lambda_10[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 48, 32, 128)  147584      ['add_10[0][0]']
#
#  lambda_11 (Lambda)             (None, 48, 32, 128)  0           ['max_pooling2d_2[0][0]']
#
#  add_11 (Add)                   (None, 48, 32, 128)  0           ['conv2d_20[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 48, 32, 128)  147584      ['add_11[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 48, 32, 512)  0           ['conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 32, 512)  262656      ['concatenate_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 16, 512)  0          ['conv2d_22[0][0]']
#
#  layer_normalization (LayerNorm  (None, 24, 16, 512)  1024       ['max_pooling2d_3[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 24, 16, 512)  1050624    ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add_12 (Add)                   (None, 24, 16, 512)  0           ['max_pooling2d_3[0][0]',
#                                                                   'multi_head_attention[0][0]']
#
#  dense (Dense)                  (None, 24, 16, 128)  65664       ['add_12[0][0]']
#
#  dense_1 (Dense)                (None, 24, 16, 512)  66048       ['dense[0][0]']
#
#  add_13 (Add)                   (None, 24, 16, 512)  0           ['add_12[0][0]',
#                                                                   'dense_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['add_13[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 512)         0           ['add_13[0][0]']
#  xPooling2D)
#
#  dense_2 (Dense)                (None, 64)           32832       ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_3 (Dense)                (None, 512)          33280       ['dense_2[0][0]',
#                                                                   'dense_2[1][0]']
#
#  add_14 (Add)                   (None, 512)          0           ['dense_3[0][0]',
#                                                                   'dense_3[1][0]']
#
#  activation (Activation)        (None, 512)          0           ['add_14[0][0]']
#
#  multiply_1 (Multiply)          (None, 24, 16, 512)  0           ['add_13[0][0]',
#                                                                   'activation[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 48, 32, 256)  1179904    ['multiply_1[0][0]']
#  ose)
#
#  concatenate_5 (Concatenate)    (None, 48, 32, 768)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 48, 32, 256)  1769728     ['concatenate_5[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 48, 32, 256)  1024       ['conv2d_23[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 48, 32, 256)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 48, 32, 256)  590080      ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 32, 256)  1024       ['conv2d_24[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 48, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['re_lu_2[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 256)         0           ['re_lu_2[0][0]']
#  MaxPooling2D)
#
#  dense_4 (Dense)                (None, 32)           8224        ['global_average_pooling2d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_1[0][0]']
#
#  dense_5 (Dense)                (None, 256)          8448        ['dense_4[0][0]',
#                                                                   'dense_4[1][0]']
#
#  add_15 (Add)                   (None, 256)          0           ['dense_5[0][0]',
#                                                                   'dense_5[1][0]']
#
#  activation_1 (Activation)      (None, 256)          0           ['add_15[0][0]']
#
#  multiply_2 (Multiply)          (None, 48, 32, 256)  0           ['re_lu_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['multiply_2[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 128)          32896       ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_7 (Dense)                (None, 256)          33024       ['dense_6[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 48, 32, 1)    257         ['multiply_2[0][0]']
#
#  multiply_3 (Multiply)          (None, 48, 32, 256)  0           ['multiply_2[0][0]',
#                                                                   'dense_7[0][0]']
#
#  multiply_4 (Multiply)          (None, 48, 32, 256)  0           ['multiply_2[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  add_16 (Add)                   (None, 48, 32, 256)  0           ['multiply_3[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 96, 64, 128)  295040     ['add_16[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 96, 64, 384)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 96, 64, 128)  442496      ['concatenate_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 96, 64, 128)  512        ['conv2d_26[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 96, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 96, 64, 128)  147584      ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 64, 128)  512        ['conv2d_27[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 96, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 192, 128, 64  73792      ['re_lu_4[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 192, 128, 19  0           ['conv2d_transpose_2[0][0]',
#                                 2)                                'conv2d_12[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 192, 128, 64  110656      ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 192, 128, 64  256        ['conv2d_28[0][0]']
#  rmalization)                   )
#
#  re_lu_5 (ReLU)                 (None, 192, 128, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 192, 128, 64  36928       ['re_lu_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 192, 128, 64  256        ['conv2d_29[0][0]']
#  rmalization)                   )
#
#  re_lu_6 (ReLU)                 (None, 192, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 384, 256, 32  18464      ['re_lu_6[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 384, 256, 96  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 384, 256, 32  27680       ['concatenate_8[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 384, 256, 32  128        ['conv2d_30[0][0]']
#  rmalization)                   )
#
#  re_lu_7 (ReLU)                 (None, 384, 256, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 384, 256, 32  9248        ['re_lu_7[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 384, 256, 32  128        ['conv2d_31[0][0]']
#  rmalization)                   )
#
#  re_lu_8 (ReLU)                 (None, 384, 256, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 384, 256, 9)  297         ['re_lu_8[0][0]']
#
# ==================================================================================================
# Total params: 7,368,251
# Trainable params: 7,366,267
# Non-trainable params: 1,984
# __________________________________________________________________________________________________
# Epoch 1/400
# 37/37 [==============================] - 68s 205ms/step - loss: 0.9228 - dice_metric: 0.1045 - iou_metric: 0.0669 - val_loss: 0.9199 - val_dice_metric: 0.1198 - val_iou_metric: 0.0757 - lr: 0.0010
# Epoch 2/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.8713 - dice_metric: 0.1780 - iou_metric: 0.1149 - val_loss: 0.9150 - val_dice_metric: 0.0780 - val_iou_metric: 0.0514 - lr: 0.0010
# Epoch 3/400
# 37/37 [==============================] - 7s 183ms/step - loss: 0.8162 - dice_metric: 0.2390 - iou_metric: 0.1611 - val_loss: 0.8949 - val_dice_metric: 0.0912 - val_iou_metric: 0.0610 - lr: 0.0010
# Epoch 4/400
# 37/37 [==============================] - 6s 162ms/step - loss: 0.7659 - dice_metric: 0.2790 - iou_metric: 0.1921 - val_loss: 0.8561 - val_dice_metric: 0.2109 - val_iou_metric: 0.1453 - lr: 0.0010
# Epoch 5/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.7222 - dice_metric: 0.3101 - iou_metric: 0.2161 - val_loss: 0.8686 - val_dice_metric: 0.1595 - val_iou_metric: 0.1022 - lr: 0.0010
# Epoch 6/400
# 37/37 [==============================] - 7s 180ms/step - loss: 0.7101 - dice_metric: 0.3113 - iou_metric: 0.2204 - val_loss: 0.7475 - val_dice_metric: 0.3046 - val_iou_metric: 0.2106 - lr: 0.0010
# Epoch 7/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.6540 - dice_metric: 0.3690 - iou_metric: 0.2669 - val_loss: 0.6540 - val_dice_metric: 0.3835 - val_iou_metric: 0.2706 - lr: 0.0010
# Epoch 8/400
# 37/37 [==============================] - 6s 170ms/step - loss: 0.6230 - dice_metric: 0.3982 - iou_metric: 0.2850 - val_loss: 0.6089 - val_dice_metric: 0.4290 - val_iou_metric: 0.3119 - lr: 0.0010
# Epoch 9/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.5992 - dice_metric: 0.4201 - iou_metric: 0.3017 - val_loss: 0.6720 - val_dice_metric: 0.3518 - val_iou_metric: 0.2436 - lr: 0.0010
# Epoch 10/400
# 37/37 [==============================] - 6s 167ms/step - loss: 0.6040 - dice_metric: 0.4110 - iou_metric: 0.2962 - val_loss: 0.5739 - val_dice_metric: 0.4385 - val_iou_metric: 0.3174 - lr: 0.0010
# Epoch 11/400
# 37/37 [==============================] - 6s 159ms/step - loss: 0.5576 - dice_metric: 0.4574 - iou_metric: 0.3344 - val_loss: 0.5273 - val_dice_metric: 0.4838 - val_iou_metric: 0.3527 - lr: 0.0010
# Epoch 12/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.5490 - dice_metric: 0.4644 - iou_metric: 0.3420 - val_loss: 0.5186 - val_dice_metric: 0.4932 - val_iou_metric: 0.3631 - lr: 0.0010
# Epoch 13/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.5539 - dice_metric: 0.4566 - iou_metric: 0.3396 - val_loss: 0.7595 - val_dice_metric: 0.2348 - val_iou_metric: 0.1613 - lr: 0.0010
# Epoch 14/400
# 37/37 [==============================] - 6s 170ms/step - loss: 0.5187 - dice_metric: 0.4926 - iou_metric: 0.3688 - val_loss: 0.5107 - val_dice_metric: 0.4912 - val_iou_metric: 0.3655 - lr: 0.0010
# Epoch 15/400
# 37/37 [==============================] - 6s 163ms/step - loss: 0.4954 - dice_metric: 0.5146 - iou_metric: 0.3920 - val_loss: 0.4500 - val_dice_metric: 0.5573 - val_iou_metric: 0.4235 - lr: 0.0010
# Epoch 16/400
# 37/37 [==============================] - 6s 156ms/step - loss: 0.5185 - dice_metric: 0.4906 - iou_metric: 0.3741 - val_loss: 0.4217 - val_dice_metric: 0.5869 - val_iou_metric: 0.4527 - lr: 0.0010
# Epoch 17/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.4703 - dice_metric: 0.5393 - iou_metric: 0.4217 - val_loss: 0.4030 - val_dice_metric: 0.6030 - val_iou_metric: 0.4735 - lr: 0.0010
# Epoch 18/400
# 37/37 [==============================] - 6s 154ms/step - loss: 0.4394 - dice_metric: 0.5777 - iou_metric: 0.4522 - val_loss: 0.3482 - val_dice_metric: 0.6682 - val_iou_metric: 0.5337 - lr: 0.0010
# Epoch 19/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.4522 - dice_metric: 0.5598 - iou_metric: 0.4404 - val_loss: 0.3455 - val_dice_metric: 0.6658 - val_iou_metric: 0.5358 - lr: 0.0010
# Epoch 20/400
# 37/37 [==============================] - 6s 163ms/step - loss: 0.4199 - dice_metric: 0.5899 - iou_metric: 0.4660 - val_loss: 0.3138 - val_dice_metric: 0.6938 - val_iou_metric: 0.5618 - lr: 0.0010
# Epoch 21/400
# 37/37 [==============================] - 6s 166ms/step - loss: 0.4056 - dice_metric: 0.6024 - iou_metric: 0.4810 - val_loss: 0.3124 - val_dice_metric: 0.6946 - val_iou_metric: 0.5649 - lr: 0.0010
# Epoch 22/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.4094 - dice_metric: 0.5979 - iou_metric: 0.4793 - val_loss: 0.3359 - val_dice_metric: 0.6708 - val_iou_metric: 0.5407 - lr: 0.0010
# Epoch 23/400
# 37/37 [==============================] - 6s 164ms/step - loss: 0.4067 - dice_metric: 0.5998 - iou_metric: 0.4786 - val_loss: 0.3078 - val_dice_metric: 0.6987 - val_iou_metric: 0.5703 - lr: 0.0010
# Epoch 24/400
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3836 - dice_metric: 0.6229 - iou_metric: 0.5013 - val_loss: 0.3063 - val_dice_metric: 0.6979 - val_iou_metric: 0.5659 - lr: 0.0010
# Epoch 25/400
# 37/37 [==============================] - 6s 159ms/step - loss: 0.3737 - dice_metric: 0.6324 - iou_metric: 0.5087 - val_loss: 0.2965 - val_dice_metric: 0.7069 - val_iou_metric: 0.5760 - lr: 0.0010
# Epoch 26/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.3992 - dice_metric: 0.6075 - iou_metric: 0.4855 - val_loss: 0.3402 - val_dice_metric: 0.6661 - val_iou_metric: 0.5350 - lr: 0.0010
# Epoch 27/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.4127 - dice_metric: 0.5922 - iou_metric: 0.4781 - val_loss: 0.3132 - val_dice_metric: 0.6893 - val_iou_metric: 0.5576 - lr: 0.0010
# Epoch 28/400
# 37/37 [==============================] - 5s 131ms/step - loss: 0.3411 - dice_metric: 0.6639 - iou_metric: 0.5354 - val_loss: 0.3039 - val_dice_metric: 0.7009 - val_iou_metric: 0.5706 - lr: 0.0010
# Epoch 29/400
# 37/37 [==============================] - 7s 175ms/step - loss: 0.3430 - dice_metric: 0.6621 - iou_metric: 0.5350 - val_loss: 0.2837 - val_dice_metric: 0.7196 - val_iou_metric: 0.5905 - lr: 0.0010
# Epoch 30/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.3693 - dice_metric: 0.6353 - iou_metric: 0.5144 - val_loss: 0.3016 - val_dice_metric: 0.7044 - val_iou_metric: 0.5740 - lr: 0.0010
# Epoch 31/400
# 37/37 [==============================] - 6s 169ms/step - loss: 0.3686 - dice_metric: 0.6351 - iou_metric: 0.5178 - val_loss: 0.2829 - val_dice_metric: 0.7205 - val_iou_metric: 0.5924 - lr: 0.0010
# Epoch 32/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.3499 - dice_metric: 0.6547 - iou_metric: 0.5328 - val_loss: 0.2932 - val_dice_metric: 0.7106 - val_iou_metric: 0.5804 - lr: 0.0010
# Epoch 33/400
# 37/37 [==============================] - 6s 157ms/step - loss: 0.3317 - dice_metric: 0.6724 - iou_metric: 0.5510 - val_loss: 0.2783 - val_dice_metric: 0.7252 - val_iou_metric: 0.6003 - lr: 0.0010
# Epoch 34/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.3517 - dice_metric: 0.6518 - iou_metric: 0.5335 - val_loss: 0.2865 - val_dice_metric: 0.7195 - val_iou_metric: 0.5941 - lr: 0.0010
# Epoch 35/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.3332 - dice_metric: 0.6704 - iou_metric: 0.5478 - val_loss: 0.2834 - val_dice_metric: 0.7178 - val_iou_metric: 0.5895 - lr: 0.0010
# Epoch 36/400
# 37/37 [==============================] - 5s 144ms/step - loss: 0.3347 - dice_metric: 0.6686 - iou_metric: 0.5467 - val_loss: 0.2979 - val_dice_metric: 0.7020 - val_iou_metric: 0.5682 - lr: 0.0010
# Epoch 37/400
# 37/37 [==============================] - 6s 169ms/step - loss: 0.3220 - dice_metric: 0.6811 - iou_metric: 0.5617 - val_loss: 0.2630 - val_dice_metric: 0.7391 - val_iou_metric: 0.6123 - lr: 0.0010
# Epoch 38/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.3520 - dice_metric: 0.6508 - iou_metric: 0.5360 - val_loss: 0.2846 - val_dice_metric: 0.7207 - val_iou_metric: 0.5942 - lr: 0.0010
# Epoch 39/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.3529 - dice_metric: 0.6497 - iou_metric: 0.5341 - val_loss: 0.3106 - val_dice_metric: 0.6920 - val_iou_metric: 0.5649 - lr: 0.0010
# Epoch 40/400
# 37/37 [==============================] - 7s 171ms/step - loss: 0.3419 - dice_metric: 0.6610 - iou_metric: 0.5464 - val_loss: 0.2623 - val_dice_metric: 0.7412 - val_iou_metric: 0.6168 - lr: 0.0010
# Epoch 41/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.3456 - dice_metric: 0.6577 - iou_metric: 0.5386 - val_loss: 0.2663 - val_dice_metric: 0.7368 - val_iou_metric: 0.6117 - lr: 0.0010
# Epoch 42/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.3321 - dice_metric: 0.6706 - iou_metric: 0.5541 - val_loss: 0.2721 - val_dice_metric: 0.7310 - val_iou_metric: 0.6051 - lr: 0.0010
# Epoch 43/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.3486 - dice_metric: 0.6546 - iou_metric: 0.5366 - val_loss: 0.2745 - val_dice_metric: 0.7275 - val_iou_metric: 0.5995 - lr: 0.0010
# Epoch 44/400
# 37/37 [==============================] - 6s 170ms/step - loss: 0.3508 - dice_metric: 0.6516 - iou_metric: 0.5367 - val_loss: 0.2575 - val_dice_metric: 0.7453 - val_iou_metric: 0.6206 - lr: 0.0010
# Epoch 45/400
# 37/37 [==============================] - 6s 163ms/step - loss: 0.3073 - dice_metric: 0.6956 - iou_metric: 0.5729 - val_loss: 0.2574 - val_dice_metric: 0.7457 - val_iou_metric: 0.6209 - lr: 0.0010
# Epoch 46/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.3287 - dice_metric: 0.6737 - iou_metric: 0.5588 - val_loss: 0.2628 - val_dice_metric: 0.7387 - val_iou_metric: 0.6119 - lr: 0.0010
# Epoch 47/400
# 37/37 [==============================] - 5s 142ms/step - loss: 0.3081 - dice_metric: 0.6949 - iou_metric: 0.5734 - val_loss: 0.2897 - val_dice_metric: 0.7148 - val_iou_metric: 0.5879 - lr: 0.0010
# Epoch 48/400
# 37/37 [==============================] - 5s 146ms/step - loss: 0.3281 - dice_metric: 0.6745 - iou_metric: 0.5569 - val_loss: 0.2667 - val_dice_metric: 0.7344 - val_iou_metric: 0.6095 - lr: 0.0010
# Epoch 49/400
# 37/37 [==============================] - 6s 158ms/step - loss: 0.3406 - dice_metric: 0.6615 - iou_metric: 0.5492 - val_loss: 0.2522 - val_dice_metric: 0.7491 - val_iou_metric: 0.6265 - lr: 0.0010
# Epoch 50/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.3339 - dice_metric: 0.6683 - iou_metric: 0.5542 - val_loss: 0.2628 - val_dice_metric: 0.7373 - val_iou_metric: 0.6105 - lr: 0.0010
# Epoch 51/400
# 37/37 [==============================] - 6s 172ms/step - loss: 0.3108 - dice_metric: 0.6915 - iou_metric: 0.5728 - val_loss: 0.2475 - val_dice_metric: 0.7551 - val_iou_metric: 0.6327 - lr: 0.0010
# Epoch 52/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.3282 - dice_metric: 0.6742 - iou_metric: 0.5595 - val_loss: 0.2570 - val_dice_metric: 0.7437 - val_iou_metric: 0.6172 - lr: 0.0010
# Epoch 53/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.3263 - dice_metric: 0.6757 - iou_metric: 0.5598 - val_loss: 0.2666 - val_dice_metric: 0.7365 - val_iou_metric: 0.6133 - lr: 0.0010
# Epoch 54/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2966 - dice_metric: 0.7057 - iou_metric: 0.5839 - val_loss: 0.2592 - val_dice_metric: 0.7421 - val_iou_metric: 0.6156 - lr: 0.0010
# Epoch 55/400
# ...
# Epoch 327/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2531 - dice_metric: 0.7477 - iou_metric: 0.6431 - val_loss: 0.2263 - val_dice_metric: 0.7744 - val_iou_metric: 0.6566 - lr: 3.1250e-05
# Epoch 328/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2639 - dice_metric: 0.7368 - iou_metric: 0.6336 - val_loss: 0.2265 - val_dice_metric: 0.7744 - val_iou_metric: 0.6566 - lr: 3.1250e-05
# Epoch 329/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.2611 - dice_metric: 0.7397 - iou_metric: 0.6399 - val_loss: 0.2271 - val_dice_metric: 0.7739 - val_iou_metric: 0.6562 - lr: 3.1250e-05
# Epoch 330/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2366 - dice_metric: 0.7641 - iou_metric: 0.6612 - val_loss: 0.2262 - val_dice_metric: 0.7747 - val_iou_metric: 0.6571 - lr: 3.1250e-05
# Epoch 331/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.2486 - dice_metric: 0.7522 - iou_metric: 0.6476 - val_loss: 0.2267 - val_dice_metric: 0.7741 - val_iou_metric: 0.6563 - lr: 3.1250e-05
# Epoch 332/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2322 - dice_metric: 0.7687 - iou_metric: 0.6672 - val_loss: 0.2263 - val_dice_metric: 0.7746 - val_iou_metric: 0.6569 - lr: 3.1250e-05
# Epoch 333/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2310 - dice_metric: 0.7696 - iou_metric: 0.6644 - val_loss: 0.2262 - val_dice_metric: 0.7748 - val_iou_metric: 0.6570 - lr: 3.1250e-05
# Epoch 334/400
# 37/37 [==============================] - 5s 143ms/step - loss: 0.2762 - dice_metric: 0.7244 - iou_metric: 0.6219 - val_loss: 0.2263 - val_dice_metric: 0.7746 - val_iou_metric: 0.6569 - lr: 3.1250e-05
# Epoch 335/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2552 - dice_metric: 0.7456 - iou_metric: 0.6449 - val_loss: 0.2258 - val_dice_metric: 0.7751 - val_iou_metric: 0.6574 - lr: 3.1250e-05
# Epoch 336/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2604 - dice_metric: 0.7404 - iou_metric: 0.6365 - val_loss: 0.2263 - val_dice_metric: 0.7745 - val_iou_metric: 0.6568 - lr: 3.1250e-05
# Epoch 337/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2262 - dice_metric: 0.7744 - iou_metric: 0.6701 - val_loss: 0.2262 - val_dice_metric: 0.7748 - val_iou_metric: 0.6572 - lr: 3.1250e-05
# Epoch 338/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2218 - dice_metric: 0.7788 - iou_metric: 0.6742 - val_loss: 0.2268 - val_dice_metric: 0.7745 - val_iou_metric: 0.6568 - lr: 3.1250e-05
# Epoch 339/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2622 - dice_metric: 0.7385 - iou_metric: 0.6385 - val_loss: 0.2264 - val_dice_metric: 0.7746 - val_iou_metric: 0.6571 - lr: 3.1250e-05
# Epoch 340/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2257 - dice_metric: 0.7750 - iou_metric: 0.6709 - val_loss: 0.2261 - val_dice_metric: 0.7747 - val_iou_metric: 0.6572 - lr: 3.1250e-05
# Epoch 341/400
# 37/37 [==============================] - 5s 143ms/step - loss: 0.2531 - dice_metric: 0.7474 - iou_metric: 0.6453 - val_loss: 0.2278 - val_dice_metric: 0.7734 - val_iou_metric: 0.6556 - lr: 3.1250e-05
# Epoch 342/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2391 - dice_metric: 0.7618 - iou_metric: 0.6584 - val_loss: 0.2267 - val_dice_metric: 0.7744 - val_iou_metric: 0.6567 - lr: 3.1250e-05
# Epoch 343/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2277 - dice_metric: 0.7729 - iou_metric: 0.6683 - val_loss: 0.2269 - val_dice_metric: 0.7740 - val_iou_metric: 0.6562 - lr: 3.1250e-05
# Epoch 344/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2537 - dice_metric: 0.7469 - iou_metric: 0.6438 - val_loss: 0.2265 - val_dice_metric: 0.7746 - val_iou_metric: 0.6568 - lr: 3.1250e-05
# Epoch 345/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2445 - dice_metric: 0.7560 - iou_metric: 0.6511 - val_loss: 0.2266 - val_dice_metric: 0.7744 - val_iou_metric: 0.6567 - lr: 3.1250e-05
# Epoch 346/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.1971 - dice_metric: 0.8038 - iou_metric: 0.6968 - val_loss: 0.2264 - val_dice_metric: 0.7747 - val_iou_metric: 0.6571 - lr: 3.1250e-05
# Epoch 347/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2205 - dice_metric: 0.7801 - iou_metric: 0.6772 - val_loss: 0.2264 - val_dice_metric: 0.7746 - val_iou_metric: 0.6569 - lr: 3.1250e-05
# Epoch 348/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2276 - dice_metric: 0.7730 - iou_metric: 0.6692 - val_loss: 0.2278 - val_dice_metric: 0.7732 - val_iou_metric: 0.6550 - lr: 3.1250e-05
# Epoch 349/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2566 - dice_metric: 0.7441 - iou_metric: 0.6383 - val_loss: 0.2257 - val_dice_metric: 0.7753 - val_iou_metric: 0.6576 - lr: 3.1250e-05
# Epoch 350/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2370 - dice_metric: 0.7636 - iou_metric: 0.6584 - val_loss: 0.2272 - val_dice_metric: 0.7742 - val_iou_metric: 0.6562 - lr: 3.1250e-05
# Epoch 351/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2429 - dice_metric: 0.7578 - iou_metric: 0.6570 - val_loss: 0.2271 - val_dice_metric: 0.7740 - val_iou_metric: 0.6562 - lr: 3.1250e-05
# Epoch 352/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2594 - dice_metric: 0.7411 - iou_metric: 0.6387 - val_loss: 0.2266 - val_dice_metric: 0.7743 - val_iou_metric: 0.6566 - lr: 1.5625e-05
# Epoch 353/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.2427 - dice_metric: 0.7580 - iou_metric: 0.6559 - val_loss: 0.2264 - val_dice_metric: 0.7746 - val_iou_metric: 0.6569 - lr: 1.5625e-05
# Epoch 354/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2529 - dice_metric: 0.7478 - iou_metric: 0.6459 - val_loss: 0.2270 - val_dice_metric: 0.7741 - val_iou_metric: 0.6563 - lr: 1.5625e-05
# Epoch 355/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2404 - dice_metric: 0.7603 - iou_metric: 0.6567 - val_loss: 0.2265 - val_dice_metric: 0.7745 - val_iou_metric: 0.6567 - lr: 1.5625e-05
# Epoch 356/400
# 37/37 [==============================] - 5s 143ms/step - loss: 0.2569 - dice_metric: 0.7439 - iou_metric: 0.6419 - val_loss: 0.2267 - val_dice_metric: 0.7744 - val_iou_metric: 0.6565 - lr: 1.5625e-05
# Epoch 357/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2542 - dice_metric: 0.7465 - iou_metric: 0.6439 - val_loss: 0.2261 - val_dice_metric: 0.7750 - val_iou_metric: 0.6573 - lr: 1.5625e-05
# Epoch 358/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2475 - dice_metric: 0.7532 - iou_metric: 0.6499 - val_loss: 0.2267 - val_dice_metric: 0.7743 - val_iou_metric: 0.6565 - lr: 1.5625e-05
# Epoch 359/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2186 - dice_metric: 0.7820 - iou_metric: 0.6755 - val_loss: 0.2272 - val_dice_metric: 0.7738 - val_iou_metric: 0.6560 - lr: 1.5625e-05
# Epoch 360/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2416 - dice_metric: 0.7590 - iou_metric: 0.6580 - val_loss: 0.2279 - val_dice_metric: 0.7732 - val_iou_metric: 0.6551 - lr: 1.5625e-05
# Epoch 361/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2457 - dice_metric: 0.7549 - iou_metric: 0.6494 - val_loss: 0.2271 - val_dice_metric: 0.7740 - val_iou_metric: 0.6561 - lr: 1.5625e-05
# Epoch 362/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2523 - dice_metric: 0.7483 - iou_metric: 0.6459 - val_loss: 0.2272 - val_dice_metric: 0.7739 - val_iou_metric: 0.6560 - lr: 1.5625e-05
# Epoch 363/400
# 37/37 [==============================] - 5s 134ms/step - loss: 0.2497 - dice_metric: 0.7510 - iou_metric: 0.6495 - val_loss: 0.2274 - val_dice_metric: 0.7737 - val_iou_metric: 0.6558 - lr: 1.5625e-05
# Epoch 364/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.2509 - dice_metric: 0.7499 - iou_metric: 0.6512 - val_loss: 0.2270 - val_dice_metric: 0.7741 - val_iou_metric: 0.6564 - lr: 1.5625e-05
# Epoch 365/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2306 - dice_metric: 0.7701 - iou_metric: 0.6670 - val_loss: 0.2265 - val_dice_metric: 0.7744 - val_iou_metric: 0.6568 - lr: 1.5625e-05
# Epoch 366/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2394 - dice_metric: 0.7613 - iou_metric: 0.6609 - val_loss: 0.2261 - val_dice_metric: 0.7749 - val_iou_metric: 0.6574 - lr: 1.5625e-05
# Epoch 367/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2394 - dice_metric: 0.7612 - iou_metric: 0.6582 - val_loss: 0.2260 - val_dice_metric: 0.7750 - val_iou_metric: 0.6575 - lr: 1.5625e-05
# Epoch 368/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2590 - dice_metric: 0.7417 - iou_metric: 0.6414 - val_loss: 0.2259 - val_dice_metric: 0.7753 - val_iou_metric: 0.6579 - lr: 1.5625e-05
# Epoch 369/400
# 37/37 [==============================] - 5s 131ms/step - loss: 0.2474 - dice_metric: 0.7532 - iou_metric: 0.6505 - val_loss: 0.2264 - val_dice_metric: 0.7747 - val_iou_metric: 0.6571 - lr: 1.5625e-05
# Epoch 370/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2721 - dice_metric: 0.7285 - iou_metric: 0.6274 - val_loss: 0.2267 - val_dice_metric: 0.7744 - val_iou_metric: 0.6568 - lr: 1.5625e-05
# Epoch 371/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2271 - dice_metric: 0.7736 - iou_metric: 0.6694 - val_loss: 0.2275 - val_dice_metric: 0.7736 - val_iou_metric: 0.6557 - lr: 1.5625e-05
# Epoch 372/400
# 37/37 [==============================] - 5s 143ms/step - loss: 0.2200 - dice_metric: 0.7807 - iou_metric: 0.6739 - val_loss: 0.2273 - val_dice_metric: 0.7739 - val_iou_metric: 0.6561 - lr: 1.5625e-05
# Epoch 373/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2132 - dice_metric: 0.7875 - iou_metric: 0.6822 - val_loss: 0.2262 - val_dice_metric: 0.7749 - val_iou_metric: 0.6571 - lr: 1.5625e-05
# Epoch 374/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.2038 - dice_metric: 0.7968 - iou_metric: 0.6905 - val_loss: 0.2265 - val_dice_metric: 0.7747 - val_iou_metric: 0.6568 - lr: 1.5625e-05
# Epoch 375/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2392 - dice_metric: 0.7616 - iou_metric: 0.6598 - val_loss: 0.2260 - val_dice_metric: 0.7748 - val_iou_metric: 0.6571 - lr: 1.5625e-05
# Epoch 376/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2460 - dice_metric: 0.7546 - iou_metric: 0.6497 - val_loss: 0.2257 - val_dice_metric: 0.7751 - val_iou_metric: 0.6575 - lr: 1.5625e-05
# Epoch 377/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2378 - dice_metric: 0.7629 - iou_metric: 0.6603 - val_loss: 0.2253 - val_dice_metric: 0.7755 - val_iou_metric: 0.6580 - lr: 1.5625e-05
# Epoch 378/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2575 - dice_metric: 0.7432 - iou_metric: 0.6397 - val_loss: 0.2252 - val_dice_metric: 0.7757 - val_iou_metric: 0.6583 - lr: 1.5625e-05
# Epoch 379/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2617 - dice_metric: 0.7390 - iou_metric: 0.6355 - val_loss: 0.2258 - val_dice_metric: 0.7751 - val_iou_metric: 0.6574 - lr: 1.5625e-05
# Epoch 380/400
# 37/37 [==============================] - 5s 131ms/step - loss: 0.2881 - dice_metric: 0.7126 - iou_metric: 0.6159 - val_loss: 0.2259 - val_dice_metric: 0.7750 - val_iou_metric: 0.6573 - lr: 1.5625e-05
# Epoch 381/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2494 - dice_metric: 0.7513 - iou_metric: 0.6472 - val_loss: 0.2261 - val_dice_metric: 0.7748 - val_iou_metric: 0.6570 - lr: 1.5625e-05
# Epoch 382/400
# 37/37 [==============================] - 5s 143ms/step - loss: 0.2618 - dice_metric: 0.7388 - iou_metric: 0.6365 - val_loss: 0.2261 - val_dice_metric: 0.7747 - val_iou_metric: 0.6570 - lr: 7.8125e-06
# Epoch 383/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2358 - dice_metric: 0.7649 - iou_metric: 0.6607 - val_loss: 0.2263 - val_dice_metric: 0.7748 - val_iou_metric: 0.6571 - lr: 7.8125e-06
# Epoch 384/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2444 - dice_metric: 0.7564 - iou_metric: 0.6536 - val_loss: 0.2261 - val_dice_metric: 0.7750 - val_iou_metric: 0.6573 - lr: 7.8125e-06
# Epoch 385/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2348 - dice_metric: 0.7658 - iou_metric: 0.6651 - val_loss: 0.2263 - val_dice_metric: 0.7748 - val_iou_metric: 0.6572 - lr: 7.8125e-06
# Epoch 386/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2625 - dice_metric: 0.7382 - iou_metric: 0.6351 - val_loss: 0.2264 - val_dice_metric: 0.7748 - val_iou_metric: 0.6571 - lr: 7.8125e-06
# Epoch 387/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2384 - dice_metric: 0.7624 - iou_metric: 0.6585 - val_loss: 0.2263 - val_dice_metric: 0.7748 - val_iou_metric: 0.6571 - lr: 7.8125e-06
# Epoch 388/400
# 37/37 [==============================] - 5s 140ms/step - loss: 0.2456 - dice_metric: 0.7551 - iou_metric: 0.6524 - val_loss: 0.2260 - val_dice_metric: 0.7751 - val_iou_metric: 0.6575 - lr: 7.8125e-06
# Epoch 389/400
# 37/37 [==============================] - 5s 138ms/step - loss: 0.2419 - dice_metric: 0.7587 - iou_metric: 0.6552 - val_loss: 0.2266 - val_dice_metric: 0.7744 - val_iou_metric: 0.6566 - lr: 7.8125e-06
# Epoch 390/400
# 37/37 [==============================] - 5s 139ms/step - loss: 0.2438 - dice_metric: 0.7570 - iou_metric: 0.6566 - val_loss: 0.2266 - val_dice_metric: 0.7745 - val_iou_metric: 0.6567 - lr: 7.8125e-06
# Epoch 391/400
# 37/37 [==============================] - 5s 132ms/step - loss: 0.2363 - dice_metric: 0.7645 - iou_metric: 0.6623 - val_loss: 0.2265 - val_dice_metric: 0.7746 - val_iou_metric: 0.6568 - lr: 7.8125e-06
# Epoch 392/400
# 37/37 [==============================] - 5s 133ms/step - loss: 0.2636 - dice_metric: 0.7370 - iou_metric: 0.6375 - val_loss: 0.2268 - val_dice_metric: 0.7743 - val_iou_metric: 0.6565 - lr: 7.8125e-06
# Epoch 393/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2729 - dice_metric: 0.7278 - iou_metric: 0.6268 - val_loss: 0.2265 - val_dice_metric: 0.7747 - val_iou_metric: 0.6570 - lr: 7.8125e-06
# Epoch 394/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2310 - dice_metric: 0.7698 - iou_metric: 0.6661 - val_loss: 0.2262 - val_dice_metric: 0.7749 - val_iou_metric: 0.6572 - lr: 7.8125e-06
# Epoch 395/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2342 - dice_metric: 0.7665 - iou_metric: 0.6625 - val_loss: 0.2260 - val_dice_metric: 0.7752 - val_iou_metric: 0.6576 - lr: 7.8125e-06
# Epoch 396/400
# 37/37 [==============================] - 5s 136ms/step - loss: 0.2353 - dice_metric: 0.7655 - iou_metric: 0.6616 - val_loss: 0.2258 - val_dice_metric: 0.7755 - val_iou_metric: 0.6579 - lr: 7.8125e-06
# Epoch 397/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2575 - dice_metric: 0.7432 - iou_metric: 0.6418 - val_loss: 0.2257 - val_dice_metric: 0.7755 - val_iou_metric: 0.6578 - lr: 7.8125e-06
# Epoch 398/400
# 37/37 [==============================] - 5s 135ms/step - loss: 0.2398 - dice_metric: 0.7609 - iou_metric: 0.6567 - val_loss: 0.2260 - val_dice_metric: 0.7752 - val_iou_metric: 0.6575 - lr: 7.8125e-06
# Epoch 399/400
# 37/37 [==============================] - 5s 137ms/step - loss: 0.2354 - dice_metric: 0.7654 - iou_metric: 0.6612 - val_loss: 0.2259 - val_dice_metric: 0.7752 - val_iou_metric: 0.6576 - lr: 7.8125e-06
# Epoch 400/400
# 37/37 [==============================] - 5s 141ms/step - loss: 0.2699 - dice_metric: 0.7308 - iou_metric: 0.6279 - val_loss: 0.2263 - val_dice_metric: 0.7748 - val_iou_metric: 0.6570 - lr: 7.8125e-06
